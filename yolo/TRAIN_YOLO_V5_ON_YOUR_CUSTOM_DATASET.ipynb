# %% [markdown]
# # UNZIPPING THE DATASET

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/wheat plant /
# !pwd
# Out:
# /content/drive/MyDrive/wheat plant
# /content/drive/MyDrive/wheat plant

# %%
# !unzip -q /content/PlantDoc.v1-resize-416x416.yolov5pytorch.zip
# Out:
# unzip:  cannot find or open /content/PlantDoc.v1-resize-416x416.yolov5pytorch.zip, /content/PlantDoc.v1-resize-416x416.yolov5pytorch.zip.zip or /content/PlantDoc.v1-resize-416x416.yolov5pytorch.zip.ZIP.

# %%
# !pwd
# Out:
# /content/drive/MyDrive/wheat plant

# %% [markdown]
# #CLONING THE YOLO-V5 FILES FROM OFFICIAL REPOSITORY

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15305, done.
# remote: Total 15305 (delta 0), reused 0 (delta 0), pack-reused 15305
# Receiving objects: 100% (15305/15305), 14.13 MiB | 16.07 MiB/s, done.
# Resolving deltas: 100% (10501/10501), done.

# %% [markdown]
# # CHANGING THE DIRECTORY

# %%
# %cd yolov5/
# Out:
# /content/drive/MyDrive/wheat plant /yolov5

# %% [markdown]
# #INSTALLING THE DEPENDENCIES

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 KB 11.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 60.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 8.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 63.4.3
#     Uninstalling setuptools-63.4.3:
#       Successfully uninstalled setuptools-63.4.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.9.0 requires jedi>=0.10, which is not installed.
# cvxpy 1.3.0 requires setuptools<=64.0.2, but you have setuptools 67.6.0 which is incompatible.
# ...

# %% [markdown]
# # DOWNLOADING ALL VERSIONS OF YOLO-V5 MODEL

# %%
# !/content/drive/MyDrive/wheat plant /yolov5/weights/download_weights.sh
# Out:
# /bin/bash: /content/drive/MyDrive/wheat: No such file or directory

# %% [markdown]
# # STEPS BEFORE TRAINING CUSTOM DATASET:
# 1. Go to yolov5/data/
# 2. Open coco128.yaml
# 3. Edit the following inside it:
#
#
#       1.   Training and Test file path
#       2.   Number of classes and Class names.

# %% [markdown]
# # TRAINING THE YOLO-V5 MODEL

# %%
# !python train.py --img 416 --batch 8 --epochs 50 --data coco128.yaml --weights yolov5s.pt --nosave --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=coco128.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=8, imgsz=416, rect=False, resume=False, nosave=True, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# fatal: cannot change to '/content/drive/MyDrive/wheat': No such file or directory
# YOLOv5 🚀 2023-3-22 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %% [markdown]
# # VISUALIZING THE TRAINING METRICS

# %%
# %load_ext tensorboard
# %tensorboard --logdir runs/train
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6006 (pid 2900), started 0:13:22 ago. (Use '!kill 2900' to kill it.)

# %% [markdown]
# # TESTING

# %%
# !python test.py --weights /content/drive/MyDrive/wheat plant /yolov5/runs/train/exp2/weights/best.pt --data coco128.yaml --img 416
# Out:
# python3: can't open file '/content/drive/MyDrive/wheat plant /yolov5/test.py': [Errno 2] No such file or directory

# %% [markdown]
# # DETECTING ON NEW IMAGES

# %%
# !python detect.py --source /content/drive/MyDrive/wheat plant /CNN/trai/wheat-septoria --weights /content/drive/MyDrive/wheat plant /yolov5/runs/train/exp2/weights/best.pt --img 416 --save-txt --save-conf
# Out:
# usage: detect.py
#        [-h]
#        [--weights WEIGHTS [WEIGHTS ...]]
#        [--source SOURCE]
#        [--data DATA]
#        [--imgsz IMGSZ [IMGSZ ...]]
#        [--conf-thres CONF_THRES]
#        [--iou-thres IOU_THRES]
#        [--max-det MAX_DET]
#        [--device DEVICE]
#        [--view-img]
#        [--save-txt]
#        [--save-conf]
#        [--save-crop]
#        [--nosave]
#        [--classes CLASSES [CLASSES ...]]
#        [--agnostic-nms]
#        [--augment]
#        [--visualize]
#        [--update]
#        [--project PROJECT]
#        [--name NAME]
#        [--exist-ok]
#        [--line-thickness LINE_THICKNESS]
#        [--hide-labels]
#        [--hide-conf]
#        [--half]
#        [--dnn]
#        [--vid-stride VID_STRIDE]
# detect.py: error: unrecognized arguments: plant /CNN/trai/wheat-septoria

# %% [markdown]
# #RETRAINING FROM THE LAST CHECKPOINT

# %%
# !python train.py --weights /content/drive/MyDrive/wheat plant /yolov5/runs/train/exp2/weights/last.pt --epochs 100 --img 416
# Out:
# usage: train.py
#        [-h]
#        [--weights WEIGHTS]
#        [--cfg CFG]
#        [--data DATA]
#        [--hyp HYP]
#        [--epochs EPOCHS]
#        [--batch-size BATCH_SIZE]
#        [--imgsz IMGSZ]
#        [--rect]
#        [--resume [RESUME]]
#        [--nosave]
#        [--noval]
#        [--noautoanchor]
#        [--noplots]
#        [--evolve [EVOLVE]]
#        [--bucket BUCKET]
#        [--cache [CACHE]]
#        [--image-weights]
#        [--device DEVICE]
#        [--multi-scale]
#        [--single-cls]
#        [--optimizer {SGD,Adam,AdamW}]
#        [--sync-bn]
#        [--workers WORKERS]
#        [--project PROJECT]
#        [--name NAME]
#        [--exist-ok]
#        [--quad]
#        [--cos-lr]
#        [--label-smoothing LABEL_SMOOTHING]
#        [--patience PATIENCE]
#        [--freeze FREEZE [FREEZE ...]]
#        [--save-period SAVE_PERIOD]
#        [--seed SEED]
#        [--local_rank LOCAL_RANK]
#        [--entity ENTITY]
# ...

# %%
import re
path='/content/drive/MyDrive/wheat plant /yolov5/runs/detect/exp/labels/11_image.txt'
myfile=open(path,'r')
lines=myfile.readlines()
pattern= "class_name"

cordinate = []
for line in lines:
  for x in line.splitlines():
    cordinate.append([x[1:]])
#   if re.search(pattern,line):
#     Cord_Raw=line
# Cord=Cord_Raw.split("(")[1].split(")")[0].split("  ")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-31-4746d0c00f11> in <module>
#       1 import re
#       2 path='/content/drive/MyDrive/wheat plant /yolov5/runs/detect/exp/labels/11_image.txt'
# ----> 3 myfile=open(path,'r')
#       4 lines=myfile.readlines()
#       5 pattern= "class_name"
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/wheat plant /yolov5/runs/detect/exp/labels/11_image.txt'

# %%
cordinate

# %%
cordinate[0]

# %%
import cv2
img = cv2.imread("/content/drive/MyDrive/images/train/11_image.jpg")
print(img.shape)
for i in cordinate:
  count= 0
  for val in i:
    value = val.strip().split(" ")
    x_min = int(float(value[0])*img.shape[0])
    x_max = x_min + int(float(value[2])*img.shape[0])
    y_min = int(float(value[1])*img.shape[1])
    y_max = y_min + int(float(value[3])*img.shape[1])
    crop_img = img[y_min:y_max, x_min:x_max]
    cv2.imwrite(f"Object_{count}.jpg",crop_img)
    count = count + 1

# %%
import cv2
img = cv2.imread("/content/drive/MyDrive/images/train/11_image.jpg")
crop_img = img[y_min:y_max, x_min:x_max]
cv2.imwrite("Object.jpg",crop_img)
